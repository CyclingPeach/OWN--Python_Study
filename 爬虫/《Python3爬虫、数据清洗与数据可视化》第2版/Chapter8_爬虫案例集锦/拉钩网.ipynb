# %%
import requests
from bs4 import BeautifulSoup


headers = {
    'Cookie':'JSESSIONID=ABAAAECABIEACCA24EE679F637F021D21E6CAA0BDE933CB; sajssdk_2015_cross_new_user=1; Hm_lvt_4233e74dff0ae5bd0a3d81c6ccf756e6=1651057428; _ga=GA1.2.1328937754.1651057429; _gid=GA1.2.1431608967.1651057429; user_trace_token=20220427190349-95b9dcf4-978c-481f-ab09-56af5553c036; LGSID=20220427190349-5e0a7dc7-b815-4969-a7e5-10e9b2a10eb2; PRE_UTM=; PRE_HOST=; PRE_SITE=; PRE_LAND=https://passport.lagou.com/login/login.html?signature=20BAF7DA2EF7E0865786A1A1D4CA88A2&service=http%253A%252F%252Fwww.lagou.com%252Fjobs&action=login&serviceId=lagou&ts=1651057422729; LGUID=20220427190349-9a30b077-22ff-4f0e-81c1-f5fb071b39bf; gate_login_token=f7df40724b9caaed4718434ef7d65dde7e9fca596c2bffecf39b7d8926632da6; LG_HAS_LOGIN=1; _putrc=96CCC65AA7D810A9123F89F2B170EADC; login=true; hasDeliver=0; privacyPolicyPopup=false; WEBTJ-ID=20220427190458-1806ab21addd6f-0999e354a7a5c7-5b4c7c4c-1013526-1806ab21adec0f; sensorsdata2015session={}; unick=陶; __lg_stoken__=fc3d41356fdec55180087ecff7909f55b4bd0279dcc6c2e4fde61c96bdc7075c61b2ea01fd4aa16609e4912fbe41c97610794b09380ee8393e9f268bbc12316c3fc53d8e17e7; _gat=1; X_MIDDLE_TOKEN=ef00374a2b4a20dddd4c1d55e28a68b3; sensorsdata2015jssdkcross={"distinct_id":"24421420","$device_id":"1806ab104781a0-0f8ea9554c700b-5b4c7c4c-1013526-1806ab1047947f","props":{"$latest_traffic_source_type":"直接流量","$latest_referrer":"","$latest_search_keyword":"未取到值_直接打开","$os":"UNIX","$browser":"Chrome","$browser_version":"100.0.4896.127","lagou_company_id":""},"first_id":"1806ab104781a0-0f8ea9554c700b-5b4c7c4c-1013526-1806ab1047947f"}; TG-TRACK-CODE=search_code; Hm_lpvt_4233e74dff0ae5bd0a3d81c6ccf756e6=1651057930; LGRID=20220427191211-a79fa0bb-08fc-4701-b632-d1c8e5e50467; SEARCH_ID=0436ccac163740309285bf777970c6ee; X_HTTP_TOKEN=ac3fa77d9f5c5cf873975015615e6bd4e5745f8492'
}

url = 'https://www.lagou.com/jobs/positionAjax.json?px=new&needAddtionalResult=false'

res = requests.post(url)
res
# Out:
# <Response [200]>

# %%
import requests
import time
#设置请求表头
header={
    'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.127 Safari/537.36',
    'Accept':'application/json, text/javascript, */*; q=0.01',
    'Accept-Encoding':'gzip, deflate, br',
    'Accept-Language':'en-US,en;q=0.9,zh-CN;q=0.8,zh;q=0.7',
    'Connection':'keep-alive',
}
#设置cookies
cookies = {
    'Cookie':'JSESSIONID=ABAAAECABIEACCA24EE679F637F021D21E6CAA0BDE933CB; sajssdk_2015_cross_new_user=1; Hm_lvt_4233e74dff0ae5bd0a3d81c6ccf756e6=1651057428; _ga=GA1.2.1328937754.1651057429; _gid=GA1.2.1431608967.1651057429; user_trace_token=20220427190349-95b9dcf4-978c-481f-ab09-56af5553c036; LGSID=20220427190349-5e0a7dc7-b815-4969-a7e5-10e9b2a10eb2; PRE_UTM=; PRE_HOST=; PRE_SITE=; PRE_LAND=https://passport.lagou.com/login/login.html?signature=20BAF7DA2EF7E0865786A1A1D4CA88A2&service=http%253A%252F%252Fwww.lagou.com%252Fjobs&action=login&serviceId=lagou&ts=1651057422729; LGUID=20220427190349-9a30b077-22ff-4f0e-81c1-f5fb071b39bf; gate_login_token=f7df40724b9caaed4718434ef7d65dde7e9fca596c2bffecf39b7d8926632da6; LG_HAS_LOGIN=1; _putrc=96CCC65AA7D810A9123F89F2B170EADC; login=true; hasDeliver=0; privacyPolicyPopup=false; WEBTJ-ID=20220427190458-1806ab21addd6f-0999e354a7a5c7-5b4c7c4c-1013526-1806ab21adec0f; sensorsdata2015session={}; unick=陶; __lg_stoken__=fc3d41356fdec55180087ecff7909f55b4bd0279dcc6c2e4fde61c96bdc7075c61b2ea01fd4aa16609e4912fbe41c97610794b09380ee8393e9f268bbc12316c3fc53d8e17e7; _gat=1; X_MIDDLE_TOKEN=ef00374a2b4a20dddd4c1d55e28a68b3; sensorsdata2015jssdkcross={"distinct_id":"24421420","$device_id":"1806ab104781a0-0f8ea9554c700b-5b4c7c4c-1013526-1806ab1047947f","props":{"$latest_traffic_source_type":"直接流量","$latest_referrer":"","$latest_search_keyword":"未取到值_直接打开","$os":"UNIX","$browser":"Chrome","$browser_version":"100.0.4896.127","lagou_company_id":""},"first_id":"1806ab104781a0-0f8ea9554c700b-5b4c7c4c-1013526-1806ab1047947f"}; TG-TRACK-CODE=search_code; Hm_lpvt_4233e74dff0ae5bd0a3d81c6ccf756e6=1651057930; LGRID=20220427191211-a79fa0bb-08fc-4701-b632-d1c8e5e50467; SEARCH_ID=0436ccac163740309285bf777970c6ee; X_HTTP_TOKEN=ac3fa77d9f5c5cf873975015615e6bd4e5745f8492'
    }
#循环采集10页数据
for i in range(0,10):
    data = {
        'first': False,
        'pn': i,#控制页码参数
        'kd': 'python',
    }
    url = 'https://www.lagou.com/jobs/positionAjax.json?needAddtionalResult=false'
    response_data = requests.post(url=url, cookies=cookies, headers=headers, data=data).text
    response_data.encoding = 'utf-8'
    print(response_data)
    time.sleep(2)
    break
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# /home/tzy/文档/Project/OWN--Python_Study/爬虫/《Python3爬虫、数据清洗与数据可视化》第2版/Chapter8_爬虫案例集锦/拉钩网.ipynb Cell 2' in <cell line: 16>()
#      <a href='vscode-notebook-cell:/home/tzy/%E6%96%87%E6%A1%A3/Project/OWN--Python_Study/%E7%88%AC%E8%99%AB/%E3%80%8APython3%E7%88%AC%E8%99%AB%E3%80%81%E6%95%B0%E6%8D%AE%E6%B8%85%E6%B4%97%E4%B8%8E%E6%95%B0%E6%8D%AE%E5%8F%AF%E8%A7%86%E5%8C%96%E3%80%8B%E7%AC%AC2%E7%89%88/Chapter8_%E7%88%AC%E8%99%AB%E6%A1%88%E4%BE%8B%E9%9B%86%E9%94%A6/%E6%8B%89%E9%92%A9%E7%BD%91.ipynb#ch0000005?line=16'>17</a> data = {
# ...

# %%
response_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/tzy/文档/Project/OWN--Python_Study/爬虫/《Python3爬虫、数据清洗与数据可视化》第2版/Chapter8_爬虫案例集锦/拉钩网.ipynb Cell 3' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/tzy/%E6%96%87%E6%A1%A3/Project/OWN--Python_Study/%E7%88%AC%E8%99%AB/%E3%80%8APython3%E7%88%AC%E8%99%AB%E3%80%81%E6%95%B0%E6%8D%AE%E6%B8%85%E6%B4%97%E4%B8%8E%E6%95%B0%E6%8D%AE%E5%8F%AF%E8%A7%86%E5%8C%96%E3%80%8B%E7%AC%AC2%E7%89%88/Chapter8_%E7%88%AC%E8%99%AB%E6%A1%88%E4%BE%8B%E9%9B%86%E9%94%A6/%E6%8B%89%E9%92%A9%E7%BD%91.ipynb#ch0000006?line=0'>1</a> response_data
#
# NameError: name 'response_data' is not defined
